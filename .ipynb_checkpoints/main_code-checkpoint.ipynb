# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


#importing machine learning libraries
import tensorflow as tf
# from tensorflow.kears.models import In
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


#Secondary imports
import pandas_profiling as pp

# %% [markdown]
# ## Reading Datasets

# %%
train = pd.read_csv('train_file.csv')
test = pd.read_csv('test_file.csv')

# %% [raw]
# pp_train = pp.ProfileReport(train)
# pp_test = pp.ProfileReport(test)
#
# pp_train.to_file('train_analysis.html')
# pp_test.to_file('test_analysis.html')

# %%
sorted(train.columns)
# Out:
# ['ACCOUNT NUMBER',
#  'ADDRESS',
#  'APPLICATION CREATED DATE',
#  'APPLICATION REQUIREMENTS COMPLETE',
#  'APPLICATION TYPE',
#  'CITY',
#  'CONDITIONAL APPROVAL',
#  'DATE ISSUED',
#  'DOING BUSINESS AS NAME',
#  'ID',
#  'LATITUDE',
#  'LEGAL NAME',
#  'LICENSE APPROVED FOR ISSUANCE',
#  'LICENSE CODE',
#  'LICENSE DESCRIPTION',
#  'LICENSE ID',
#  'LICENSE NUMBER',
#  'LICENSE STATUS',
#  'LICENSE STATUS CHANGE DATE',
#  'LICENSE TERM EXPIRATION DATE',
#  'LICENSE TERM START DATE',
#  'LOCATION',
#  'LONGITUDE',
#  'PAYMENT DATE',
#  'POLICE DISTRICT',
#  'PRECINCT',
#  'SITE NUMBER',
#  'SSA',
#  'STATE',
#  'WARD',
#  'WARD PRECINCT',
#  'ZIP CODE']

# %%
#Finding duration of license, as it's probably an important factor

train['LICENSE_DURATION'] = list(map(lambda x, y: (x - y).days, pd.to_datetime(train['LICENSE TERM EXPIRATION DATE']), pd.to_datetime(train['LICENSE TERM START DATE'])))
test['LICENSE_DURATION'] = list(map(lambda x, y: (x - y).days, pd.to_datetime(test['LICENSE TERM EXPIRATION DATE']), pd.to_datetime(test['LICENSE TERM START DATE'])))

# %%
temp = []
base = list(map(lambda x: str(x),pd.to_datetime(train['LICENSE STATUS CHANGE DATE']).values ))


for i in range(len(base)):
    if base[i] !='NaT':
        temp.append(1)
    else:
        temp.append(0)
    
    
train['LICENSE_CHANGE'] = temp

temp = []
base = list(map(lambda x: str(x),pd.to_datetime(test['LICENSE STATUS CHANGE DATE']).values ))


for i in range(len(base)):
    if base[i] !='NaT':
        temp.append(1)
    else:
        temp.append(0)
    
    
test['LICENSE_CHANGE'] = temp

# %%
'''So the set of features I'll be using from the first analysis (mentioned in the approach file) will be, ['SITE_NUMBER', 'CITY', 'STATE', 'WARD', 
 'LICENSE_CODE', 'LICENSE_DESCRIPTION', 'LICENSE_TERM_START_DATE' - 'LICENSE_TERM_EXPIRATION_DATE' in days], 
Later I might use other variables as well'''


features = ['SITE NUMBER', 'CITY', 'STATE', 'LICENSE CODE','LICENSE DESCRIPTION', 'LICENSE_DURATION', 'LICENSE_CHANGE']

# %%
train['LICENSE DESCRIPTION'].shape
# Out:
# (85895,)

# %%
test['LICENSE DESCRIPTION'].shape
# Out:
# (57239,)

# %%
85895 + 57239
# Out:
# 143134

# %%
lbl1 = LabelEncoder()
lbl2 = LabelEncoder()
lbl3 = LabelEncoder()
lbl4 = LabelEncoder()


lbl1.fit(pd.concat((train['LICENSE DESCRIPTION'], test['LICENSE DESCRIPTION']), axis=0))
train['LICENSE DESCRIPTION'] = lbl1.transform(train['LICENSE DESCRIPTION'])
test['LICENSE DESCRIPTION'] = lbl1.transform(test['LICENSE DESCRIPTION'])
                                              
lbl2.fit(pd.concat((train['CITY'], test['CITY']), axis=0))
train['CITY'] = lbl2.transform(train['CITY'])
test['CITY'] = lbl2.transform(test['CITY'])
                                              
                                              
lbl3.fit(pd.concat((train['STATE'], test['STATE']), axis=0))
train['STATE'] = lbl3.transform(train['STATE'])
test['STATE'] = lbl3.transform(test['STATE'])
                                              
lbl4.fit(train['LICENSE STATUS'])
train['LICENSE STATUS'] = lbl4.transform(train['LICENSE STATUS'])

# %%
trainx, testx, trainy, testy = train_test_split(train[features].values, train['LICENSE STATUS'].values, test_size = 0.2)

# %% [markdown]
# ### Starting construction of models

# %%
# This returns a tensor
input_features = Input(shape=(7,))

# a layer instance is callable on a tensor, and returns a tensor
output_1 = Dense(10, activation='relu')(input_features)
output_2 = Dense(10, activation='relu')(output_1)
predictions = Dense(5, activation='softmax')(output_2)

# This creates a model that includes
# the Input layer and three Dense layers
model = Model(inputs=input_features, outputs=predictions)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_crossentropy'])

checkpoint_path = 'tmp/model_1.ckpt'
early_stopping = EarlyStopping(monitor='val_sparse_categorical_crossentropy',patience=7, verbose=1)
model_checkpoint = ModelCheckpoint(checkpoint_path,monitor='val_sparse_categorical_crossentropy',save_best_only=True, verbose=1)
print('Model Built', model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 7)                 0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                80
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_38 (Dense)             (None, 5)                 55
# =================================================================
# Total params: 245
# Trainable params: 245
# Non-trainable params: 0
# _________________________________________________________________
# Model Built None

# %%
if os.path.isdir("tmp"):
    pass
else:
    os.mkdir('tmp/')

# %%
model.fit(trainx, trainy,
          validation_data=(testx, testy)
          ,epochs = 10000, 
          batch_size = 5000,
          callbacks = [early_stopping, model_checkpoint]
         )
# Out:
# Train on 68716 samples, validate on 17179 samples
# Epoch 1/10000
#  5000/68716 [=>............................] - ETA: 1s - loss: 4.2649 - sparse_categorical_crossentropy: 4.2649
# Epoch 00001: val_sparse_categorical_crossentropy improved from inf to 1.59199, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 1s 8us/sample - loss: 1.7955 - sparse_categorical_crossentropy: 1.7955 - val_loss: 1.5920 - val_sparse_categorical_crossentropy: 1.5920
# Epoch 2/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.5921 - sparse_categorical_crossentropy: 1.5921
# Epoch 00002: val_sparse_categorical_crossentropy improved from 1.59199 to 1.57191, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.5829 - sparse_categorical_crossentropy: 1.5829 - val_loss: 1.5719 - val_sparse_categorical_crossentropy: 1.5719
# Epoch 3/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.5717 - sparse_categorical_crossentropy: 1.5717
# Epoch 00003: val_sparse_categorical_crossentropy improved from 1.57191 to 1.55138, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.5626 - sparse_categorical_crossentropy: 1.5626 - val_loss: 1.5514 - val_sparse_categorical_crossentropy: 1.5514
# Epoch 4/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.5514 - sparse_categorical_crossentropy: 1.5514
# Epoch 00004: val_sparse_categorical_crossentropy improved from 1.55138 to 1.53045, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.5418 - sparse_categorical_crossentropy: 1.5418 - val_loss: 1.5304 - val_sparse_categorical_crossentropy: 1.5304
# Epoch 5/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.5305 - sparse_categorical_crossentropy: 1.5305
# Epoch 00005: val_sparse_categorical_crossentropy improved from 1.53045 to 1.50907, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.5207 - sparse_categorical_crossentropy: 1.5207 - val_loss: 1.5091 - val_sparse_categorical_crossentropy: 1.5091
# Epoch 6/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.5094 - sparse_categorical_crossentropy: 1.5094
# Epoch 00006: val_sparse_categorical_crossentropy improved from 1.50907 to 1.48728, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.4991 - sparse_categorical_crossentropy: 1.4991 - val_loss: 1.4873 - val_sparse_categorical_crossentropy: 1.4873
# Epoch 7/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.4870 - sparse_categorical_crossentropy: 1.4870
# Epoch 00007: val_sparse_categorical_crossentropy improved from 1.48728 to 1.46505, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.4771 - sparse_categorical_crossentropy: 1.4771 - val_loss: 1.4651 - val_sparse_categorical_crossentropy: 1.4651
# Epoch 8/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.4654 - sparse_categorical_crossentropy: 1.4654
# Epoch 00008: val_sparse_categorical_crossentropy improved from 1.46505 to 1.44247, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.4547 - sparse_categorical_crossentropy: 1.4547 - val_loss: 1.4425 - val_sparse_categorical_crossentropy: 1.4425
# Epoch 9/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.4419 - sparse_categorical_crossentropy: 1.4419
# Epoch 00009: val_sparse_categorical_crossentropy improved from 1.44247 to 1.41957, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.4320 - sparse_categorical_crossentropy: 1.4320 - val_loss: 1.4196 - val_sparse_categorical_crossentropy: 1.4196
# Epoch 10/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.4191 - sparse_categorical_crossentropy: 1.4191
# Epoch 00010: val_sparse_categorical_crossentropy improved from 1.41957 to 1.39641, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.4089 - sparse_categorical_crossentropy: 1.4089 - val_loss: 1.3964 - val_sparse_categorical_crossentropy: 1.3964
# Epoch 11/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.3968 - sparse_categorical_crossentropy: 1.3968
# Epoch 00011: val_sparse_categorical_crossentropy improved from 1.39641 to 1.37304, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.3856 - sparse_categorical_crossentropy: 1.3856 - val_loss: 1.3730 - val_sparse_categorical_crossentropy: 1.3730
# Epoch 12/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.3732 - sparse_categorical_crossentropy: 1.3732
# Epoch 00012: val_sparse_categorical_crossentropy improved from 1.37304 to 1.34954, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.3622 - sparse_categorical_crossentropy: 1.3622 - val_loss: 1.3495 - val_sparse_categorical_crossentropy: 1.3495
# Epoch 13/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.3479 - sparse_categorical_crossentropy: 1.3479
# Epoch 00013: val_sparse_categorical_crossentropy improved from 1.34954 to 1.32597, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.3386 - sparse_categorical_crossentropy: 1.3386 - val_loss: 1.3260 - val_sparse_categorical_crossentropy: 1.3260
# Epoch 14/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.3246 - sparse_categorical_crossentropy: 1.3246
# Epoch 00014: val_sparse_categorical_crossentropy improved from 1.32597 to 1.30242, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.3150 - sparse_categorical_crossentropy: 1.3150 - val_loss: 1.3024 - val_sparse_categorical_crossentropy: 1.3024
# Epoch 15/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.3029 - sparse_categorical_crossentropy: 1.3029
# Epoch 00015: val_sparse_categorical_crossentropy improved from 1.30242 to 1.27896, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.2915 - sparse_categorical_crossentropy: 1.2915 - val_loss: 1.2790 - val_sparse_categorical_crossentropy: 1.2790
# Epoch 16/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 1.2687 - sparse_categorical_crossentropy: 1.2687
# Epoch 00016: val_sparse_categorical_crossentropy improved from 1.27896 to 1.25564, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.2681 - sparse_categorical_crossentropy: 1.2681 - val_loss: 1.2556 - val_sparse_categorical_crossentropy: 1.2556
# Epoch 17/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 1.2454 - sparse_categorical_crossentropy: 1.2454
# Epoch 00017: val_sparse_categorical_crossentropy improved from 1.25564 to 1.23256, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.2449 - sparse_categorical_crossentropy: 1.2449 - val_loss: 1.2326 - val_sparse_categorical_crossentropy: 1.2326
# Epoch 18/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.2337 - sparse_categorical_crossentropy: 1.2337
# Epoch 00018: val_sparse_categorical_crossentropy improved from 1.23256 to 1.20978, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.2219 - sparse_categorical_crossentropy: 1.2219 - val_loss: 1.2098 - val_sparse_categorical_crossentropy: 1.2098
# Epoch 19/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.2099 - sparse_categorical_crossentropy: 1.2099
# Epoch 00019: val_sparse_categorical_crossentropy improved from 1.20978 to 1.18735, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.1993 - sparse_categorical_crossentropy: 1.1993 - val_loss: 1.1873 - val_sparse_categorical_crossentropy: 1.1873
# Epoch 20/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.1860 - sparse_categorical_crossentropy: 1.1860
# Epoch 00020: val_sparse_categorical_crossentropy improved from 1.18735 to 1.16532, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.1770 - sparse_categorical_crossentropy: 1.1770 - val_loss: 1.1653 - val_sparse_categorical_crossentropy: 1.1653
# Epoch 21/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.1612 - sparse_categorical_crossentropy: 1.1612
# Epoch 00021: val_sparse_categorical_crossentropy improved from 1.16532 to 1.14378, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.1552 - sparse_categorical_crossentropy: 1.1552 - val_loss: 1.1438 - val_sparse_categorical_crossentropy: 1.1438
# Epoch 22/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.1454 - sparse_categorical_crossentropy: 1.1454
# Epoch 00022: val_sparse_categorical_crossentropy improved from 1.14378 to 1.12276, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.1339 - sparse_categorical_crossentropy: 1.1339 - val_loss: 1.1228 - val_sparse_categorical_crossentropy: 1.1228
# Epoch 23/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 1.1150 - sparse_categorical_crossentropy: 1.1150
# Epoch 00023: val_sparse_categorical_crossentropy improved from 1.12276 to 1.10231, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.1131 - sparse_categorical_crossentropy: 1.1131 - val_loss: 1.1023 - val_sparse_categorical_crossentropy: 1.1023
# Epoch 24/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0975 - sparse_categorical_crossentropy: 1.0975
# Epoch 00024: val_sparse_categorical_crossentropy improved from 1.10231 to 1.08245, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0929 - sparse_categorical_crossentropy: 1.0929 - val_loss: 1.0825 - val_sparse_categorical_crossentropy: 1.0825
# Epoch 25/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0815 - sparse_categorical_crossentropy: 1.0815
# Epoch 00025: val_sparse_categorical_crossentropy improved from 1.08245 to 1.06323, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0733 - sparse_categorical_crossentropy: 1.0733 - val_loss: 1.0632 - val_sparse_categorical_crossentropy: 1.0632
# Epoch 26/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0594 - sparse_categorical_crossentropy: 1.0594
# Epoch 00026: val_sparse_categorical_crossentropy improved from 1.06323 to 1.04467, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0544 - sparse_categorical_crossentropy: 1.0544 - val_loss: 1.0447 - val_sparse_categorical_crossentropy: 1.0447
# Epoch 27/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0458 - sparse_categorical_crossentropy: 1.0458
# Epoch 00027: val_sparse_categorical_crossentropy improved from 1.04467 to 1.02678, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0361 - sparse_categorical_crossentropy: 1.0361 - val_loss: 1.0268 - val_sparse_categorical_crossentropy: 1.0268
# Epoch 28/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0249 - sparse_categorical_crossentropy: 1.0249
# Epoch 00028: val_sparse_categorical_crossentropy improved from 1.02678 to 1.00956, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0185 - sparse_categorical_crossentropy: 1.0185 - val_loss: 1.0096 - val_sparse_categorical_crossentropy: 1.0096
# Epoch 29/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 1.0109 - sparse_categorical_crossentropy: 1.0109
# Epoch 00029: val_sparse_categorical_crossentropy improved from 1.00956 to 0.99305, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 1.0016 - sparse_categorical_crossentropy: 1.0016 - val_loss: 0.9931 - val_sparse_categorical_crossentropy: 0.9931
# Epoch 30/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.9861 - sparse_categorical_crossentropy: 0.9861
# Epoch 00030: val_sparse_categorical_crossentropy improved from 0.99305 to 0.97724, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.9854 - sparse_categorical_crossentropy: 0.9854 - val_loss: 0.9772 - val_sparse_categorical_crossentropy: 0.9772
# Epoch 31/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.9707 - sparse_categorical_crossentropy: 0.9707
# Epoch 00031: val_sparse_categorical_crossentropy improved from 0.97724 to 0.96211, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.9699 - sparse_categorical_crossentropy: 0.9699 - val_loss: 0.9621 - val_sparse_categorical_crossentropy: 0.9621
# Epoch 32/10000
# 45000/68716 [==================>...........] - ETA: 0s - loss: 0.9568 - sparse_categorical_crossentropy: 0.9568
# Epoch 00032: val_sparse_categorical_crossentropy improved from 0.96211 to 0.94768, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.9551 - sparse_categorical_crossentropy: 0.9551 - val_loss: 0.9477 - val_sparse_categorical_crossentropy: 0.9477
# Epoch 33/10000
# 45000/68716 [==================>...........] - ETA: 0s - loss: 0.9435 - sparse_categorical_crossentropy: 0.9435
# Epoch 00033: val_sparse_categorical_crossentropy improved from 0.94768 to 0.93393, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.9410 - sparse_categorical_crossentropy: 0.9410 - val_loss: 0.9339 - val_sparse_categorical_crossentropy: 0.9339
# Epoch 34/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.9286 - sparse_categorical_crossentropy: 0.9286
# Epoch 00034: val_sparse_categorical_crossentropy improved from 0.93393 to 0.92084, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.9275 - sparse_categorical_crossentropy: 0.9275 - val_loss: 0.9208 - val_sparse_categorical_crossentropy: 0.9208
# Epoch 35/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.9176 - sparse_categorical_crossentropy: 0.9176
# Epoch 00035: val_sparse_categorical_crossentropy improved from 0.92084 to 0.90839, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.9147 - sparse_categorical_crossentropy: 0.9147 - val_loss: 0.9084 - val_sparse_categorical_crossentropy: 0.9084
# Epoch 36/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.9033 - sparse_categorical_crossentropy: 0.9033
# Epoch 00036: val_sparse_categorical_crossentropy improved from 0.90839 to 0.89657, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.9025 - sparse_categorical_crossentropy: 0.9025 - val_loss: 0.8966 - val_sparse_categorical_crossentropy: 0.8966
# Epoch 37/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8957 - sparse_categorical_crossentropy: 0.8957
# Epoch 00037: val_sparse_categorical_crossentropy improved from 0.89657 to 0.88536, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8910 - sparse_categorical_crossentropy: 0.8910 - val_loss: 0.8854 - val_sparse_categorical_crossentropy: 0.8854
# Epoch 38/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8839 - sparse_categorical_crossentropy: 0.8839
# Epoch 00038: val_sparse_categorical_crossentropy improved from 0.88536 to 0.87474, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8800 - sparse_categorical_crossentropy: 0.8800 - val_loss: 0.8747 - val_sparse_categorical_crossentropy: 0.8747
# Epoch 39/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8742 - sparse_categorical_crossentropy: 0.8742
# Epoch 00039: val_sparse_categorical_crossentropy improved from 0.87474 to 0.86468, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8697 - sparse_categorical_crossentropy: 0.8697 - val_loss: 0.8647 - val_sparse_categorical_crossentropy: 0.8647
# Epoch 40/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8660 - sparse_categorical_crossentropy: 0.8660
# Epoch 00040: val_sparse_categorical_crossentropy improved from 0.86468 to 0.85516, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8599 - sparse_categorical_crossentropy: 0.8599 - val_loss: 0.8552 - val_sparse_categorical_crossentropy: 0.8552
# Epoch 41/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8574 - sparse_categorical_crossentropy: 0.8574
# Epoch 00041: val_sparse_categorical_crossentropy improved from 0.85516 to 0.84615, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8506 - sparse_categorical_crossentropy: 0.8506 - val_loss: 0.8462 - val_sparse_categorical_crossentropy: 0.8462
# Epoch 42/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8468 - sparse_categorical_crossentropy: 0.8468
# Epoch 00042: val_sparse_categorical_crossentropy improved from 0.84615 to 0.83763, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8418 - sparse_categorical_crossentropy: 0.8418 - val_loss: 0.8376 - val_sparse_categorical_crossentropy: 0.8376
# Epoch 43/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8399 - sparse_categorical_crossentropy: 0.8399
# Epoch 00043: val_sparse_categorical_crossentropy improved from 0.83763 to 0.82959, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8335 - sparse_categorical_crossentropy: 0.8335 - val_loss: 0.8296 - val_sparse_categorical_crossentropy: 0.8296
# Epoch 44/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.8281 - sparse_categorical_crossentropy: 0.8281
# Epoch 00044: val_sparse_categorical_crossentropy improved from 0.82959 to 0.82197, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8257 - sparse_categorical_crossentropy: 0.8257 - val_loss: 0.8220 - val_sparse_categorical_crossentropy: 0.8220
# Epoch 45/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.8183 - sparse_categorical_crossentropy: 0.8183
# Epoch 00045: val_sparse_categorical_crossentropy improved from 0.82197 to 0.81478, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8183 - sparse_categorical_crossentropy: 0.8183 - val_loss: 0.8148 - val_sparse_categorical_crossentropy: 0.8148
# Epoch 46/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.8115 - sparse_categorical_crossentropy: 0.8115
# Epoch 00046: val_sparse_categorical_crossentropy improved from 0.81478 to 0.80800, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8113 - sparse_categorical_crossentropy: 0.8113 - val_loss: 0.8080 - val_sparse_categorical_crossentropy: 0.8080
# Epoch 47/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7995 - sparse_categorical_crossentropy: 0.7995
# Epoch 00047: val_sparse_categorical_crossentropy improved from 0.80800 to 0.80158, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.8046 - sparse_categorical_crossentropy: 0.8046 - val_loss: 0.8016 - val_sparse_categorical_crossentropy: 0.8016
# Epoch 48/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7997 - sparse_categorical_crossentropy: 0.7997
# Epoch 00048: val_sparse_categorical_crossentropy improved from 0.80158 to 0.79551, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7984 - sparse_categorical_crossentropy: 0.7984 - val_loss: 0.7955 - val_sparse_categorical_crossentropy: 0.7955
# Epoch 49/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7934 - sparse_categorical_crossentropy: 0.7934
# Epoch 00049: val_sparse_categorical_crossentropy improved from 0.79551 to 0.78978, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7925 - sparse_categorical_crossentropy: 0.7925 - val_loss: 0.7898 - val_sparse_categorical_crossentropy: 0.7898
# Epoch 50/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7835 - sparse_categorical_crossentropy: 0.7835
# Epoch 00050: val_sparse_categorical_crossentropy improved from 0.78978 to 0.78436, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7869 - sparse_categorical_crossentropy: 0.7869 - val_loss: 0.7844 - val_sparse_categorical_crossentropy: 0.7844
# Epoch 51/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7787 - sparse_categorical_crossentropy: 0.7787
# Epoch 00051: val_sparse_categorical_crossentropy improved from 0.78436 to 0.77924, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7817 - sparse_categorical_crossentropy: 0.7817 - val_loss: 0.7792 - val_sparse_categorical_crossentropy: 0.7792
# Epoch 52/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7766 - sparse_categorical_crossentropy: 0.7766
# Epoch 00052: val_sparse_categorical_crossentropy improved from 0.77924 to 0.77439, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7767 - sparse_categorical_crossentropy: 0.7767 - val_loss: 0.7744 - val_sparse_categorical_crossentropy: 0.7744
# Epoch 53/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7772 - sparse_categorical_crossentropy: 0.7772
# Epoch 00053: val_sparse_categorical_crossentropy improved from 0.77439 to 0.76981, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7720 - sparse_categorical_crossentropy: 0.7720 - val_loss: 0.7698 - val_sparse_categorical_crossentropy: 0.7698
# Epoch 54/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7670 - sparse_categorical_crossentropy: 0.7670
# Epoch 00054: val_sparse_categorical_crossentropy improved from 0.76981 to 0.76547, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7675 - sparse_categorical_crossentropy: 0.7675 - val_loss: 0.7655 - val_sparse_categorical_crossentropy: 0.7655
# Epoch 55/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7625 - sparse_categorical_crossentropy: 0.7625
# Epoch 00055: val_sparse_categorical_crossentropy improved from 0.76547 to 0.76137, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7633 - sparse_categorical_crossentropy: 0.7633 - val_loss: 0.7614 - val_sparse_categorical_crossentropy: 0.7614
# Epoch 56/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.7593 - sparse_categorical_crossentropy: 0.7593
# Epoch 00056: val_sparse_categorical_crossentropy improved from 0.76137 to 0.75748, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7593 - sparse_categorical_crossentropy: 0.7593 - val_loss: 0.7575 - val_sparse_categorical_crossentropy: 0.7575
# Epoch 57/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7561 - sparse_categorical_crossentropy: 0.7561
# Epoch 00057: val_sparse_categorical_crossentropy improved from 0.75748 to 0.75379, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7555 - sparse_categorical_crossentropy: 0.7555 - val_loss: 0.7538 - val_sparse_categorical_crossentropy: 0.7538
# Epoch 58/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7521 - sparse_categorical_crossentropy: 0.7521
# Epoch 00058: val_sparse_categorical_crossentropy improved from 0.75379 to 0.75030, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7519 - sparse_categorical_crossentropy: 0.7519 - val_loss: 0.7503 - val_sparse_categorical_crossentropy: 0.7503
# Epoch 59/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7435 - sparse_categorical_crossentropy: 0.7435
# Epoch 00059: val_sparse_categorical_crossentropy improved from 0.75030 to 0.74698, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7485 - sparse_categorical_crossentropy: 0.7485 - val_loss: 0.7470 - val_sparse_categorical_crossentropy: 0.7470
# Epoch 60/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7424 - sparse_categorical_crossentropy: 0.7424
# Epoch 00060: val_sparse_categorical_crossentropy improved from 0.74698 to 0.74384, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7453 - sparse_categorical_crossentropy: 0.7453 - val_loss: 0.7438 - val_sparse_categorical_crossentropy: 0.7438
# Epoch 61/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7424 - sparse_categorical_crossentropy: 0.7424
# Epoch 00061: val_sparse_categorical_crossentropy improved from 0.74384 to 0.74086, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7423 - sparse_categorical_crossentropy: 0.7423 - val_loss: 0.7409 - val_sparse_categorical_crossentropy: 0.7409
# Epoch 62/10000
# 45000/68716 [==================>...........] - ETA: 0s - loss: 0.7390 - sparse_categorical_crossentropy: 0.7390
# Epoch 00062: val_sparse_categorical_crossentropy improved from 0.74086 to 0.73802, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7394 - sparse_categorical_crossentropy: 0.7394 - val_loss: 0.7380 - val_sparse_categorical_crossentropy: 0.7380
# Epoch 63/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7394 - sparse_categorical_crossentropy: 0.7394
# Epoch 00063: val_sparse_categorical_crossentropy improved from 0.73802 to 0.73533, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7366 - sparse_categorical_crossentropy: 0.7366 - val_loss: 0.7353 - val_sparse_categorical_crossentropy: 0.7353
# Epoch 64/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.7342 - sparse_categorical_crossentropy: 0.7342
# Epoch 00064: val_sparse_categorical_crossentropy improved from 0.73533 to 0.73277, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7340 - sparse_categorical_crossentropy: 0.7340 - val_loss: 0.7328 - val_sparse_categorical_crossentropy: 0.7328
# Epoch 65/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.7324 - sparse_categorical_crossentropy: 0.7324
# Epoch 00065: val_sparse_categorical_crossentropy improved from 0.73277 to 0.73034, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7315 - sparse_categorical_crossentropy: 0.7315 - val_loss: 0.7303 - val_sparse_categorical_crossentropy: 0.7303
# Epoch 66/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7293 - sparse_categorical_crossentropy: 0.7293
# Epoch 00066: val_sparse_categorical_crossentropy improved from 0.73034 to 0.72802, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7291 - sparse_categorical_crossentropy: 0.7291 - val_loss: 0.7280 - val_sparse_categorical_crossentropy: 0.7280
# Epoch 67/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7306 - sparse_categorical_crossentropy: 0.7306
# Epoch 00067: val_sparse_categorical_crossentropy improved from 0.72802 to 0.72581, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7269 - sparse_categorical_crossentropy: 0.7269 - val_loss: 0.7258 - val_sparse_categorical_crossentropy: 0.7258
# Epoch 68/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.7252 - sparse_categorical_crossentropy: 0.7252
# Epoch 00068: val_sparse_categorical_crossentropy improved from 0.72581 to 0.72372, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7248 - sparse_categorical_crossentropy: 0.7248 - val_loss: 0.7237 - val_sparse_categorical_crossentropy: 0.7237
# Epoch 69/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7232 - sparse_categorical_crossentropy: 0.7232
# Epoch 00069: val_sparse_categorical_crossentropy improved from 0.72372 to 0.72172, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7227 - sparse_categorical_crossentropy: 0.7227 - val_loss: 0.7217 - val_sparse_categorical_crossentropy: 0.7217
# Epoch 70/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.7207 - sparse_categorical_crossentropy: 0.7207
# Epoch 00070: val_sparse_categorical_crossentropy improved from 0.72172 to 0.71981, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7208 - sparse_categorical_crossentropy: 0.7208 - val_loss: 0.7198 - val_sparse_categorical_crossentropy: 0.7198
# Epoch 71/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7191 - sparse_categorical_crossentropy: 0.7191
# Epoch 00071: val_sparse_categorical_crossentropy improved from 0.71981 to 0.71799, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7189 - sparse_categorical_crossentropy: 0.7189 - val_loss: 0.7180 - val_sparse_categorical_crossentropy: 0.7180
# Epoch 72/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7129 - sparse_categorical_crossentropy: 0.7129
# Epoch 00072: val_sparse_categorical_crossentropy improved from 0.71799 to 0.71626, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7172 - sparse_categorical_crossentropy: 0.7172 - val_loss: 0.7163 - val_sparse_categorical_crossentropy: 0.7163
# Epoch 73/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7153 - sparse_categorical_crossentropy: 0.7153
# Epoch 00073: val_sparse_categorical_crossentropy improved from 0.71626 to 0.71460, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7155 - sparse_categorical_crossentropy: 0.7155 - val_loss: 0.7146 - val_sparse_categorical_crossentropy: 0.7146
# Epoch 74/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.7132 - sparse_categorical_crossentropy: 0.7132
# Epoch 00074: val_sparse_categorical_crossentropy improved from 0.71460 to 0.71302, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7139 - sparse_categorical_crossentropy: 0.7139 - val_loss: 0.7130 - val_sparse_categorical_crossentropy: 0.7130
# Epoch 75/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.7125 - sparse_categorical_crossentropy: 0.7125
# Epoch 00075: val_sparse_categorical_crossentropy improved from 0.71302 to 0.71152, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7124 - sparse_categorical_crossentropy: 0.7124 - val_loss: 0.7115 - val_sparse_categorical_crossentropy: 0.7115
# Epoch 76/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7104 - sparse_categorical_crossentropy: 0.7104
# Epoch 00076: val_sparse_categorical_crossentropy improved from 0.71152 to 0.71007, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7109 - sparse_categorical_crossentropy: 0.7109 - val_loss: 0.7101 - val_sparse_categorical_crossentropy: 0.7101
# Epoch 77/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7095 - sparse_categorical_crossentropy: 0.7095
# Epoch 00077: val_sparse_categorical_crossentropy improved from 0.71007 to 0.70869, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7095 - sparse_categorical_crossentropy: 0.7095 - val_loss: 0.7087 - val_sparse_categorical_crossentropy: 0.7087
# Epoch 78/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7160 - sparse_categorical_crossentropy: 0.7160
# Epoch 00078: val_sparse_categorical_crossentropy improved from 0.70869 to 0.70737, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7082 - sparse_categorical_crossentropy: 0.7082 - val_loss: 0.7074 - val_sparse_categorical_crossentropy: 0.7074
# Epoch 79/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.7058 - sparse_categorical_crossentropy: 0.7058
# Epoch 00079: val_sparse_categorical_crossentropy improved from 0.70737 to 0.70611, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7069 - sparse_categorical_crossentropy: 0.7069 - val_loss: 0.7061 - val_sparse_categorical_crossentropy: 0.7061
# Epoch 80/10000
# 45000/68716 [==================>...........] - ETA: 0s - loss: 0.7057 - sparse_categorical_crossentropy: 0.7057
# Epoch 00080: val_sparse_categorical_crossentropy improved from 0.70611 to 0.70491, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7057 - sparse_categorical_crossentropy: 0.7057 - val_loss: 0.7049 - val_sparse_categorical_crossentropy: 0.7049
# Epoch 81/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.7046 - sparse_categorical_crossentropy: 0.7046
# Epoch 00081: val_sparse_categorical_crossentropy improved from 0.70491 to 0.70374, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7045 - sparse_categorical_crossentropy: 0.7045 - val_loss: 0.7037 - val_sparse_categorical_crossentropy: 0.7037
# Epoch 82/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.7024 - sparse_categorical_crossentropy: 0.7024
# Epoch 00082: val_sparse_categorical_crossentropy improved from 0.70374 to 0.70264, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7034 - sparse_categorical_crossentropy: 0.7034 - val_loss: 0.7026 - val_sparse_categorical_crossentropy: 0.7026
# Epoch 83/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6905 - sparse_categorical_crossentropy: 0.6905
# Epoch 00083: val_sparse_categorical_crossentropy improved from 0.70264 to 0.70157, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7023 - sparse_categorical_crossentropy: 0.7023 - val_loss: 0.7016 - val_sparse_categorical_crossentropy: 0.7016
# Epoch 84/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7034 - sparse_categorical_crossentropy: 0.7034
# Epoch 00084: val_sparse_categorical_crossentropy improved from 0.70157 to 0.70056, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.7013 - sparse_categorical_crossentropy: 0.7013 - val_loss: 0.7006 - val_sparse_categorical_crossentropy: 0.7006
# Epoch 85/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.7005 - sparse_categorical_crossentropy: 0.7005
# Epoch 00085: val_sparse_categorical_crossentropy improved from 0.70056 to 0.69958, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 2us/sample - loss: 0.7003 - sparse_categorical_crossentropy: 0.7003 - val_loss: 0.6996 - val_sparse_categorical_crossentropy: 0.6996
# Epoch 86/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7012 - sparse_categorical_crossentropy: 0.7012
# Epoch 00086: val_sparse_categorical_crossentropy improved from 0.69958 to 0.69864, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6993 - sparse_categorical_crossentropy: 0.6993 - val_loss: 0.6986 - val_sparse_categorical_crossentropy: 0.6986
# Epoch 87/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6987 - sparse_categorical_crossentropy: 0.6987
# Epoch 00087: val_sparse_categorical_crossentropy improved from 0.69864 to 0.69774, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6984 - sparse_categorical_crossentropy: 0.6984 - val_loss: 0.6977 - val_sparse_categorical_crossentropy: 0.6977
# Epoch 88/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7089 - sparse_categorical_crossentropy: 0.7089
# Epoch 00088: val_sparse_categorical_crossentropy improved from 0.69774 to 0.69688, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6976 - sparse_categorical_crossentropy: 0.6976 - val_loss: 0.6969 - val_sparse_categorical_crossentropy: 0.6969
# Epoch 89/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6969 - sparse_categorical_crossentropy: 0.6969
# Epoch 00089: val_sparse_categorical_crossentropy improved from 0.69688 to 0.69605, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6967 - sparse_categorical_crossentropy: 0.6967 - val_loss: 0.6960 - val_sparse_categorical_crossentropy: 0.6960
# Epoch 90/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6917 - sparse_categorical_crossentropy: 0.6917
# Epoch 00090: val_sparse_categorical_crossentropy improved from 0.69605 to 0.69525, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6959 - sparse_categorical_crossentropy: 0.6959 - val_loss: 0.6952 - val_sparse_categorical_crossentropy: 0.6952
# Epoch 91/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6932 - sparse_categorical_crossentropy: 0.6932
# Epoch 00091: val_sparse_categorical_crossentropy improved from 0.69525 to 0.69448, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 3us/sample - loss: 0.6952 - sparse_categorical_crossentropy: 0.6952 - val_loss: 0.6945 - val_sparse_categorical_crossentropy: 0.6945
# Epoch 92/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6942 - sparse_categorical_crossentropy: 0.6942
# Epoch 00092: val_sparse_categorical_crossentropy improved from 0.69448 to 0.69374, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6944 - sparse_categorical_crossentropy: 0.6944 - val_loss: 0.6937 - val_sparse_categorical_crossentropy: 0.6937
# Epoch 93/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6828 - sparse_categorical_crossentropy: 0.6828
# Epoch 00093: val_sparse_categorical_crossentropy improved from 0.69374 to 0.69303, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6937 - sparse_categorical_crossentropy: 0.6937 - val_loss: 0.6930 - val_sparse_categorical_crossentropy: 0.6930
# Epoch 94/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6959 - sparse_categorical_crossentropy: 0.6959
# Epoch 00094: val_sparse_categorical_crossentropy improved from 0.69303 to 0.69235, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6930 - sparse_categorical_crossentropy: 0.6930 - val_loss: 0.6924 - val_sparse_categorical_crossentropy: 0.6924
# Epoch 95/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6885 - sparse_categorical_crossentropy: 0.6885
# Epoch 00095: val_sparse_categorical_crossentropy improved from 0.69235 to 0.69170, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6924 - sparse_categorical_crossentropy: 0.6924 - val_loss: 0.6917 - val_sparse_categorical_crossentropy: 0.6917
# Epoch 96/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6903 - sparse_categorical_crossentropy: 0.6903
# Epoch 00096: val_sparse_categorical_crossentropy improved from 0.69170 to 0.69106, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6917 - sparse_categorical_crossentropy: 0.6917 - val_loss: 0.6911 - val_sparse_categorical_crossentropy: 0.6911
# Epoch 97/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.6914 - sparse_categorical_crossentropy: 0.6914
# Epoch 00097: val_sparse_categorical_crossentropy improved from 0.69106 to 0.69045, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6911 - sparse_categorical_crossentropy: 0.6911 - val_loss: 0.6905 - val_sparse_categorical_crossentropy: 0.6905
# Epoch 98/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.6913 - sparse_categorical_crossentropy: 0.6913
# Epoch 00098: val_sparse_categorical_crossentropy improved from 0.69045 to 0.68987, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6905 - sparse_categorical_crossentropy: 0.6905 - val_loss: 0.6899 - val_sparse_categorical_crossentropy: 0.6899
# Epoch 99/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6890 - sparse_categorical_crossentropy: 0.6890
# Epoch 00099: val_sparse_categorical_crossentropy improved from 0.68987 to 0.68930, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6900 - sparse_categorical_crossentropy: 0.6900 - val_loss: 0.6893 - val_sparse_categorical_crossentropy: 0.6893
# Epoch 100/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6801 - sparse_categorical_crossentropy: 0.6801
# Epoch 00100: val_sparse_categorical_crossentropy improved from 0.68930 to 0.68875, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6894 - sparse_categorical_crossentropy: 0.6894 - val_loss: 0.6888 - val_sparse_categorical_crossentropy: 0.6888
# Epoch 101/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6871 - sparse_categorical_crossentropy: 0.6871
# Epoch 00101: val_sparse_categorical_crossentropy improved from 0.68875 to 0.68823, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6889 - sparse_categorical_crossentropy: 0.6889 - val_loss: 0.6882 - val_sparse_categorical_crossentropy: 0.6882
# Epoch 102/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6898 - sparse_categorical_crossentropy: 0.6898
# Epoch 00102: val_sparse_categorical_crossentropy improved from 0.68823 to 0.68772, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6884 - sparse_categorical_crossentropy: 0.6884 - val_loss: 0.6877 - val_sparse_categorical_crossentropy: 0.6877
# Epoch 103/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6903 - sparse_categorical_crossentropy: 0.6903
# Epoch 00103: val_sparse_categorical_crossentropy improved from 0.68772 to 0.68723, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6879 - sparse_categorical_crossentropy: 0.6879 - val_loss: 0.6872 - val_sparse_categorical_crossentropy: 0.6872
# Epoch 104/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.7028 - sparse_categorical_crossentropy: 0.7028
# Epoch 00104: val_sparse_categorical_crossentropy improved from 0.68723 to 0.68676, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6874 - sparse_categorical_crossentropy: 0.6874 - val_loss: 0.6868 - val_sparse_categorical_crossentropy: 0.6868
# Epoch 105/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6932 - sparse_categorical_crossentropy: 0.6932
# Epoch 00105: val_sparse_categorical_crossentropy improved from 0.68676 to 0.68631, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6870 - sparse_categorical_crossentropy: 0.6870 - val_loss: 0.6863 - val_sparse_categorical_crossentropy: 0.6863
# Epoch 106/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6845 - sparse_categorical_crossentropy: 0.6845
# Epoch 00106: val_sparse_categorical_crossentropy improved from 0.68631 to 0.68587, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6866 - sparse_categorical_crossentropy: 0.6866 - val_loss: 0.6859 - val_sparse_categorical_crossentropy: 0.6859
# Epoch 107/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6825 - sparse_categorical_crossentropy: 0.6825
# Epoch 00107: val_sparse_categorical_crossentropy improved from 0.68587 to 0.68544, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6861 - sparse_categorical_crossentropy: 0.6861 - val_loss: 0.6854 - val_sparse_categorical_crossentropy: 0.6854
# Epoch 108/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6864 - sparse_categorical_crossentropy: 0.6864
# Epoch 00108: val_sparse_categorical_crossentropy improved from 0.68544 to 0.68503, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6857 - sparse_categorical_crossentropy: 0.6857 - val_loss: 0.6850 - val_sparse_categorical_crossentropy: 0.6850
# Epoch 109/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6956 - sparse_categorical_crossentropy: 0.6956
# Epoch 00109: val_sparse_categorical_crossentropy improved from 0.68503 to 0.68463, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6853 - sparse_categorical_crossentropy: 0.6853 - val_loss: 0.6846 - val_sparse_categorical_crossentropy: 0.6846
# Epoch 110/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.6862 - sparse_categorical_crossentropy: 0.6862
# Epoch 00110: val_sparse_categorical_crossentropy improved from 0.68463 to 0.68425, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6850 - sparse_categorical_crossentropy: 0.6850 - val_loss: 0.6843 - val_sparse_categorical_crossentropy: 0.6843
# Epoch 111/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6855 - sparse_categorical_crossentropy: 0.6855
# Epoch 00111: val_sparse_categorical_crossentropy improved from 0.68425 to 0.68389, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6846 - sparse_categorical_crossentropy: 0.6846 - val_loss: 0.6839 - val_sparse_categorical_crossentropy: 0.6839
# Epoch 112/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6930 - sparse_categorical_crossentropy: 0.6930
# Epoch 00112: val_sparse_categorical_crossentropy improved from 0.68389 to 0.68352, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6842 - sparse_categorical_crossentropy: 0.6842 - val_loss: 0.6835 - val_sparse_categorical_crossentropy: 0.6835
# Epoch 113/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.6849 - sparse_categorical_crossentropy: 0.6849
# ...
# Epoch 00544: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 545/10000
# 50000/68716 [====================>.........] - ETA: 0s - loss: 0.6721 - sparse_categorical_crossentropy: 0.6721
# Epoch 00545: val_sparse_categorical_crossentropy improved from 0.66927 to 0.66927, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 546/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6647 - sparse_categorical_crossentropy: 0.6647
# Epoch 00546: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6706 - sparse_categorical_crossentropy: 0.6706 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 547/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6726 - sparse_categorical_crossentropy: 0.6726
# Epoch 00547: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 548/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6700 - sparse_categorical_crossentropy: 0.6700
# Epoch 00548: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 549/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.6689 - sparse_categorical_crossentropy: 0.6689
# Epoch 00549: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 550/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6621 - sparse_categorical_crossentropy: 0.6621
# Epoch 00550: val_sparse_categorical_crossentropy improved from 0.66927 to 0.66927, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 551/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705
# Epoch 00551: val_sparse_categorical_crossentropy did not improve from 0.66927
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 552/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6616 - sparse_categorical_crossentropy: 0.6616
# Epoch 00552: val_sparse_categorical_crossentropy improved from 0.66927 to 0.66926, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 553/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6819 - sparse_categorical_crossentropy: 0.6819
# Epoch 00553: val_sparse_categorical_crossentropy did not improve from 0.66926
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 554/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6750 - sparse_categorical_crossentropy: 0.6750
# Epoch 00554: val_sparse_categorical_crossentropy improved from 0.66926 to 0.66926, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 555/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6691 - sparse_categorical_crossentropy: 0.6691
# Epoch 00555: val_sparse_categorical_crossentropy did not improve from 0.66926
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 556/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6660 - sparse_categorical_crossentropy: 0.6660
# Epoch 00556: val_sparse_categorical_crossentropy did not improve from 0.66926
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 557/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6796 - sparse_categorical_crossentropy: 0.6796
# Epoch 00557: val_sparse_categorical_crossentropy improved from 0.66926 to 0.66926, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 558/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6710 - sparse_categorical_crossentropy: 0.6710
# Epoch 00558: val_sparse_categorical_crossentropy did not improve from 0.66926
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 559/10000
# 60000/68716 [=========================>....] - ETA: 0s - loss: 0.6696 - sparse_categorical_crossentropy: 0.6696
# Epoch 00559: val_sparse_categorical_crossentropy did not improve from 0.66926
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 560/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6744 - sparse_categorical_crossentropy: 0.6744
# Epoch 00560: val_sparse_categorical_crossentropy improved from 0.66926 to 0.66925, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 561/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6706 - sparse_categorical_crossentropy: 0.6706
# Epoch 00561: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 562/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6860 - sparse_categorical_crossentropy: 0.6860
# Epoch 00562: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 563/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6718 - sparse_categorical_crossentropy: 0.6718
# Epoch 00563: val_sparse_categorical_crossentropy improved from 0.66925 to 0.66925, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 564/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6677 - sparse_categorical_crossentropy: 0.6677
# Epoch 00564: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 565/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6627 - sparse_categorical_crossentropy: 0.6627
# Epoch 00565: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 566/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6728 - sparse_categorical_crossentropy: 0.6728
# Epoch 00566: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 567/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6624 - sparse_categorical_crossentropy: 0.6624
# Epoch 00567: val_sparse_categorical_crossentropy improved from 0.66925 to 0.66925, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 568/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6734 - sparse_categorical_crossentropy: 0.6734
# Epoch 00568: val_sparse_categorical_crossentropy did not improve from 0.66925
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 569/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6709 - sparse_categorical_crossentropy: 0.6709
# Epoch 00569: val_sparse_categorical_crossentropy improved from 0.66925 to 0.66925, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 570/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6658 - sparse_categorical_crossentropy: 0.6658
# Epoch 00570: val_sparse_categorical_crossentropy improved from 0.66925 to 0.66924, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 571/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6732 - sparse_categorical_crossentropy: 0.6732
# Epoch 00571: val_sparse_categorical_crossentropy did not improve from 0.66924
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 572/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705
# Epoch 00572: val_sparse_categorical_crossentropy improved from 0.66924 to 0.66923, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 573/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6723 - sparse_categorical_crossentropy: 0.6723
# Epoch 00573: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 574/10000
# 55000/68716 [=======================>......] - ETA: 0s - loss: 0.6710 - sparse_categorical_crossentropy: 0.6710
# Epoch 00574: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 575/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6698 - sparse_categorical_crossentropy: 0.6698
# Epoch 00575: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 576/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6751 - sparse_categorical_crossentropy: 0.6751
# Epoch 00576: val_sparse_categorical_crossentropy improved from 0.66923 to 0.66923, saving model to tmp/model_1.ckpt
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 577/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6729 - sparse_categorical_crossentropy: 0.6729
# Epoch 00577: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6693 - val_sparse_categorical_crossentropy: 0.6693
# Epoch 578/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6667 - sparse_categorical_crossentropy: 0.6667
# Epoch 00578: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 579/10000
# 65000/68716 [===========================>..] - ETA: 0s - loss: 0.6706 - sparse_categorical_crossentropy: 0.6706
# Epoch 00579: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 580/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6688 - sparse_categorical_crossentropy: 0.6688
# Epoch 00580: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 581/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6687 - sparse_categorical_crossentropy: 0.6687
# Epoch 00581: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 582/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6641 - sparse_categorical_crossentropy: 0.6641
# Epoch 00582: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 583/10000
#  5000/68716 [=>............................] - ETA: 0s - loss: 0.6748 - sparse_categorical_crossentropy: 0.6748
# Epoch 00583: val_sparse_categorical_crossentropy did not improve from 0.66923
# 68716/68716 [==============================] - 0s 1us/sample - loss: 0.6705 - sparse_categorical_crossentropy: 0.6705 - val_loss: 0.6692 - val_sparse_categorical_crossentropy: 0.6692
# Epoch 00583: early stopping

# %%
result = model.predict(test[features])

# %%
resultt = np.argmax(result, axis=1)

# %%
test.shape
# Out:
# (57239, 33)

# %%
submission = pd.DataFrame()
submission['ID'] = test['LICENSE ID']
submission['LICENSE STATUS'] = lbl4.inverse_transform(resultt)

# %%
submission.to_csv('submission.csv', index=False)

# %%
np.unique(resultt, return_counts=True)
# Out:
# (array([1]), array([57239]))

# %%
np.unique(train['LICENSE STATUS'].values, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([30200, 55400,     2,     3,   290]))
